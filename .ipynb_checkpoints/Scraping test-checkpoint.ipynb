# %%
import requests
from bs4 import BeautifulSoup
import re
import selenium
import time
import pandas as pd
import random
import scraping_class
from tqdm import tqdm
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import scraping_class
from bs4 import BeautifulSoup
import re
import time

# %%
logfile = 'log_test.csv'
connector = scraping_class.Connector(logfile)

def get_links(): 
    # Connect to the url: 
    #response, call_id = connector.get(category_url, 'mapping_test')
    
    # Find the last page number: 
    #page_number_link_locations = response.text.split('Page number ')[1:]
    #page_numbers = []
    #for no in page_number_link_locations:
    #    no = no.split('"')[0]
    #    page_numbers.append(no)
    #last_page_no = int(page_numbers[-1])
    
    # Fetch the review links: 
    links = []  
    for i in tqdm(range(1, 1000)): 
        response, call_id = connector.get(f'https://www.dn.no/smak/vinsok?p={i}&price=0%5C%20%5C-%5C%20149', 'mapping')
        link_locations = response.text.split('href="')[1:]
        for link in link_locations:
            link = link.split('"')[0]
            links.append(link)
    links = [url+link for link in links if '/vin/' in link] 
    
    # Remove duplicates
    links = list(dict.fromkeys(links))
    
    return links

test = get_links()
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]
#   0%|          | 1/999 [00:00<11:33,  1.44it/s]
#   0%|          | 2/999 [00:01<10:49,  1.53it/s]
#   0%|          | 3/999 [00:01<10:19,  1.61it/s]
#   0%|          | 4/999 [00:02<09:57,  1.67it/s]
#   1%|          | 5/999 [00:02<09:40,  1.71it/s]
#   1%|          | 6/999 [00:03<09:32,  1.73it/s]
#   1%|          | 7/999 [00:04<09:22,  1.76it/s]
#   1%|          | 8/999 [00:04<09:15,  1.78it/s]
#   1%|          | 9/999 [00:05<09:11,  1.79it/s]
#   1%|          | 10/999 [00:05<09:10,  1.80it/s]
#   1%|          | 11/999 [00:06<09:09,  1.80it/s]
#   1%|          | 12/999 [00:06<09:06,  1.81it/s]
#   1%|▏         | 13/999 [00:07<09:07,  1.80it/s]
#   1%|▏         | 14/999 [00:07<09:06,  1.80it/s]
#   2%|▏         | 15/999 [00:08<09:04,  1.81it/s]
#   2%|▏         | 16/999 [00:08<09:07,  1.79it/s]
#   2%|▏         | 17/999 [00:09<09:12,  1.78it/s]
#   2%|▏         | 18/999 [00:10<09:08,  1.79it/s]
#   2%|▏         | 19/999 [00:10<09:05,  1.80it/s]
#   2%|▏         | 20/999 [00:11<09:09,  1.78it/s]
#   2%|▏         | 21/999 [00:11<09:04,  1.79it/s]
#   2%|▏         | 22/999 [00:12<09:03,  1.80it/s]
#   2%|▏         | 23/999 [00:12<09:01,  1.80it/s]
#   2%|▏         | 24/999 [00:13<08:58,  1.81it/s]
#   3%|▎         | 25/999 [00:14<09:09,  1.77it/s]
#   3%|▎         | 26/999 [00:14<09:19,  1.74it/s]
#   3%|▎         | 27/999 [00:15<09:12,  1.76it/s]
#   3%|▎         | 28/999 [00:15<09:08,  1.77it/s]
#   3%|▎         | 29/999 [00:16<09:04,  1.78it/s]
#   3%|▎         | 30/999 [00:16<09:02,  1.79it/s]
#  13%|█▎        | 125/999 [01:09<08:14,  1.77it/s]
#  13%|█▎        | 126/999 [01:10<08:10,  1.78it/s]
#  13%|█▎        | 127/999 [01:10<08:06,  1.79it/s]
#  13%|█▎        | 128/999 [01:11<08:04,  1.80it/s]
#  13%|█▎        | 129/999 [01:11<08:02,  1.80it/s]
#  13%|█▎        | 130/999 [01:12<08:01,  1.80it/s]
#  13%|█▎        | 131/999 [01:13<08:15,  1.75it/s]
#  13%|█▎        | 132/999 [01:13<08:28,  1.70it/s]
#  13%|█▎        | 133/999 [01:14<08:31,  1.69it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-18bfb1698bd9> in <module>
#      29     return links
#      30
# ---> 31 test = get_links()
#
# <ipython-input-19-18bfb1698bd9> in get_links()
#      17     links = []
#      18     for i in tqdm(range(1, 1000)):
# ---> 19         response, call_id = connector.get(f'https://www.dn.no/smak/vinsok?p={i}&price=0%5C%20%5C-%5C%20149', 'mapping')
#      20         link_locations = response.text.split('href="')[1:]
#      21         for link in link_locations:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scraping_class/scraping_class.py in get(self, url, project_name, params)
#     312             # for loop defining number of retries with the requests method.
#     313             for _ in range(self.n_tries):
# --> 314                 ratelimit()
#     315                 t = time.time()
#     316                 try:  # error handling
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scraping_class/scraping_class.py in ratelimit(duration)
#     166 def ratelimit(duration=0.5):
#     167     "A function that handles the rate of your calls."
# --> 168     time.sleep(duration)
#     169
#     170
#
# KeyboardInterrupt:

# %%
url = 'https://www.dn.no/smak/vinsok?p=2&price=0%5C%20%5C-%5C%20149'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
soup = BeautifulSoup(driver.page_source,'html')

table_nodes = soup.find_all('div', {'class':'vrs-article__body'})
# Out:
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Driver [/Users/Caroline/.wdm/drivers/chromedriver/mac64/84.0.4147.30/chromedriver] found in cache

# %%
def parse_html_tables(table_node): 
    #table_headers = table_node.thead.find_all('th')
    #table_headers = [col['aria-label'] for col in table_headers]

    table_body = table_node.tbody
    table_rows = table_body.find_all('tr')
    
    # This function extracts the information from the child and ensures the right format:
    import numpy as np
    def convert_value_text(value_node):
        if value_node.name == 'th': 
            return value_node.text
        else: # assumes node is td
            try: 
                return str(value_node.text)
            except: 
                return np.nan
    
    # This finds the children and extracts the values from all of the rows:
    row_list = []
    for row in range(len(table_rows)): 
        lst = list(table_rows[row].children)
        inner_list = []
        for col in range(len(lst)): 
            child = lst[col]
            child = convert_value_text(child)
            inner_list.append(child)
        row_list.append(inner_list)
    
    # This converts the list of lists to a dataframe:
    import pandas as pd
    #df = pd.DataFrame(row_list, columns=table_headers)
    return row_list

# %%
url = 'https://www.dn.no/smak/vinsok?p=2&price=0%5C%20%5C-%5C%20149'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
time.sleep(5)
htmlSource = driver.page_source
# Out:
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Driver [/Users/Caroline/.wdm/drivers/chromedriver/mac64/84.0.4147.30/chromedriver] found in cache

# %%
links_names = []
link_locations = htmlSource.split('href="')[1:]
for link in link_locations:
    link = link.split('</a>')[0]
    links_names.append(link)
links_names = [link for link in links_names if '/vin/' in link] 
links_names = list(dict.fromkeys(links_names))
links = []
names = []
for link in links_names:
    split = link.split('>')[0]
    name = link.split('>')[1]
    links.append(split)
    names.append(name)

# %%
# Test samlet

def retrive_names_and_links():
    driver = webdriver.Chrome(ChromeDriverManager().install())
    links_names = []
    links = []
    names = []

    for i in tqdm(range(1, 100)): 
        url = f'https://www.dn.no/smak/vinsok?p={i}&price=0%5C%20%5C-%5C%20149'
        driver.get(url)
        time.sleep(5)
        htmlSource = driver.page_source
        link_locations = htmlSource.split('href="')[1:]
        for link in link_locations:
            link = link.split('</a>')[0]
            links_names.append(link)
        links_names = [link for link in links_names if '/vin/' in link] 
        links_names = list(dict.fromkeys(links_names))
        for link in links_names:
            split = link.split('>')[0]
            name = link.split('>')[1]
            links.append(split)
            names.append(name)
        return links, names
# Out:
# [WDM] - Current google-chrome version is 84.0.4147
# [WDM] - Get LATEST driver version for 84.0.4147
# [WDM] - Driver [/Users/Caroline/.wdm/drivers/chromedriver/mac64/84.0.4147.30/chromedriver] found in cache
# 100%|██████████| 100/100 [09:36<00:00,  5.77s/it]

# %%
#display(links)
#display(names)

names = list(dict.fromkeys(names))
names
# Out:
# ['Oud Beersel Oude Kriek',
#  'Beer Geek Breakfast',
#  'Lervig Christmas Crush Barrel aged Flemmish inspired red ale',
#  'Au Baron Saint Médard Cuvée de Noël',
#  'St. Hallvards Reserve-Jul',
#  'Slogen Blond',
#  'Bareksten Rhubarb Bitter',
#  'Amundsen Rebel King Christmas',
#  'To Øl Dangerously Close to Stupid Amount of Kiwi',
#  'Boon Framboise',
#  'To Øl 8 Fruit',
#  'Ringi James Grieve',
#  'Austmann Stille Natt',
#  'Saison Dupont',
#  'Salamandre Pur Malt',
#  "N'Ice Chouffe",
#  'Nøgne Ø Two Captains',
#  'Petritegi Sidra Natural',
#  'Haandbryggeriet Fatlagret Bestefar',
#  'Guinness Special Export',
#  'Ego Brygghus The Executioner',
#  'La Valentina Spelt',
#  'Het Anker CVD Keizer Imperial Dark',
#  'Maddam Clovis &amp; François Triple',
#  'Nøgne Ø Four Shady Captains',
#  'Brasserie des Pothiers Raymonde Blonde Intrépide',
#  'La Guita Manzanilla',
#  'Balholm Cider Økologisk',
#  'Birra del Borgo Dogfish Head My Antonia',
#  'Solera Reserva Puerto Fino',
#  'Ringi Summerred Gårdspresset Eple',
#  'Saladin Paul Côtes du Rhône',
#  "Graham's 10 Years Old Tawny",
#  'Ferreira Late Bottled Vintage Porto',
#  'Brännland Pernilla Perle',
#  'La Casilla',
#  'Ayinger Celebrator Doppelbock',
#  'Nøisom Dobbelbock Juleøl',
#  'Haandbryggeriet Fatlagret JuleStout',
#  'Tripel Karmeliet',
#  'Great Divide Yeti Imperial Stout',
#  'Mario Rovira Tosca Cerrada Palomino Fino en Rama',
#  'Cinq Autels Cidre de Normandie Demi Sec',
#  'Delirium Argentum',
#  'Fjordfolk Julelager',
#  'Ægir Lindisfarne Scotch Ale',
#  'Pont de Gassac Blanc',
#  'Les Dames de Ferran',
#  'La Reserve de Ferran',
#  'Lervig Naughty &amp; Nice Doppelbock',
#  'Katlenburger Mead Dark Aronia Berry',
#  "Lindheim Farmer's Reserve Markens Grøde",
#  'Nøgne Ø Command &amp; Conquer',
#  'St. Hallvards Null Stress Abra Kabarbra',
#  'Lorenz Auslese',
#  'Kinn Uår',
#  'E.C. Dahls Sankt Olav',
#  'De Glazen Toren Lentebier',
#  'Balholm Handverk Cider med humle',
#  'Aass Juleøl Vellagret',
#  'To Øl Jule Mælk',
#  '7 Fjell 7 Sorter Christmas Ale',
#  "Churchill's White Port Dry",
#  "Churchill's Reserve Port",
#  'Cornish Orchards Gold Cider',
#  'La Chouffe Blond',
#  'Birrificio Il Mastio Drum Barrel',
#  'Casa de la Ermita Joven',
#  'Don Zoilo Pedro Ximenez 12 Years Old',
#  'Midtfyns Belgian Christmas Blonde',
#  'Ayinger Urweisse',
#  'Van Steenberge Gulden Draak',
#  'Aval Cidre Artisanal',
#  'Wimmer-Czerny Fels am Wagram Roter Veltliner',
#  'Mantlerhof Grüner Veltliner',
#  'Nøgne Ø Kriek of Telemark',
#  'Grand Mouton Extra Brut Methode Traditionelle',
#  'Bedouet Cogito',
#  '7 Fjell Morgenstemning Coffee Stout',
#  'Brekeriet Lusse Lelle',
#  "Tilquin Oude Gueuze à l'Ancienne",
#  'Balholm bringebær limonade',
#  'Kinn Vestkyst Indiaøl',
#  'Oppigårds Thurbo Stout',
#  'Brocard Sainte Claire Chablis',
#  'Topf Wechselberg Riesling',
#  "Glazen Toren Saison d'Erpe-Mere",
#  'Kreinbacher Juhfark',
#  'Gordon Xmas',
#  'Ten. S. Lucia Citrullo Indigeno',
#  'Stillwater Oude Bae',
#  'Langmann Schilcher Klassik',
#  'Thornbridge Tart',
#  'Lindheim Friendship Series Sour Flower',
#  'Ægir Dry-Hopped Maibock',
#  'Nøgne Ø Thicket &amp; Thorns',
#  'Årgang Eple og Ingefær',
#  'Trabanco Seleccionada Sidra de Asturias',
#  'OMA Dubbel',
#  'Lervig Idaho Picnic',
#  'Little Brother Grønne tre velkommen',
#  'Stigbergets Trouble Sleep Imperial Stout',
#  'Trysil Bryggeri Våghals Dobbel Dare IPA',
#  'Pardubický Porter',
#  'Palm Brugge Tripel',
#  'Clan! Destino',
#  'Ioppa Colline Novaresi Vespolina Coda Rossa',
#  'Soave Classico San Michele',
#  'Cossart Gordon 5 Years Old Verdelho',
#  'Aass Juleøl Premium',
#  'Doc`s Draft Dry Hopped Hard Apple Cider',
#  'Duvel Tripel Hop Citra',
#  'Graacher Himmelreich Riesling Kabinett halbtrocken',
#  'Erdinger Weissbier Dunkel',
#  'Bellenos Cuvée Rouge',
#  'Ch. Grand’ Grange La Cascade Beaujolais Villages',
#  'Birrificio Il Mastio Rock Noel',
#  'Jacobsen Golden Naked Christmas Ale',
#  'Erdinger Pikantus Weizenbock',
#  'Einstök lgerd Islandic Wee Heavy',
#  'Frydenlund Bokkøl',
#  'Finca Luzón Roble',
#  'Gassier Cuvée Garrigues',
#  'Avalon Farmers Reserve',
#  'Tre Monti Campo di Mezzo Sangiovese',
#  'BrewDog Native Son',
#  'Catcher in the Rye',
#  'Sagene Tannjul',
#  'Klokk &amp; Co Juicy Stuff',
#  'Põhjala Öö XO Cellar Series',
#  'Geiranger Bryggeri Kveik "Sur&amp;Snasen"',
#  'Amundsen Ink &amp; Dagger Modern Day IPA',
#  'Voss Kveika Rugøl',
#  'Nelly France Shieldmaiden CdR Village  St. Cécile',
#  'Slåtteøl',
#  'Gouden Carolus Classic',
#  'Dönnhoff Riesling',
#  'Früh Kölsch',
#  'Haandbryggeriet Earthkveik',
#  'Tall Poppy India Red Ale',
#  'Casal da Azenha Branco',
#  'Voss Bryggeri Farfars Hage',
#  'Deep Roots Riesling Trocken',
#  'Nøisom - Håndverkspils',
#  'Graff Julebokk Fatlagret',
#  'Flåklypa Spesial Juleøl vol.#2',
#  'Boscarelli Prugnolo Rosso di Montepulciano',
#  "Lindheim Farmer's Reserve Stikkelsbær",
#  'Cigar City Florida Man Double IPA',
#  'Staropramen',
#  'Jikiun Triple Decoction Imperial Pilsner',
#  'Nøgne Ø Terje',
#  'Balhom Sprudlande Margaret',
#  'Dyre Gård Økologisk Santana Eplemost',
#  'Klokk &amp; Co Chill IPA',
#  'Sundbytunet Vienna Lager',
#  'Brick &amp; Mortar Sprudlevin',
#  'Monograph Rosé',
#  '7 Fjell Julesnop White Christmas Stout',
#  'Château Barreyre',
#  'Løkka Tropicana',
#  'Fruktstereo Cider Revolution',
#  'Kupela Sagardoa',
#  'Spy Valley Easy Tiger Sauvignon Blanc',
#  'Carrascal Chardonnay',
#  'Nøisom Fruity Collision',
#  'Torraccia del Piantavigna Tre Confini Nebbiolo',
#  'Barbadillo Solear Manzanilla',
#  'Pime Öö Imperial Stout',
#  'Chamonix Rouge',
#  'San Francesco Ciro Rosato',
#  'Solar das Bouças Loureiro',
#  'Dr. Gänz Winzenheimer Rosenheck Riesling Trocken',
#  'Canti Gavi',
#  'Balholm Cider med malt',
#  'Artadi Artazuri Garnacha',
#  'Alegria Manzanilla',
#  'Familia Oliveda Cava Brut Jove',
#  'Mikkeller I Wish Gluten Free IPA',
#  'Fatt. di Scannano Chianti',
#  'Dönnhoff Riesling Trocken',
#  'St. Hallvards For-Jul',
#  'Casamatta Rosso',
#  'Helvetesgjølet Quadrupel',
#  'Dahls Juleøl',
#  'Meinklang Burgenland Red',
#  'Prà Soave Classico Otto',
#  "Moscato d'Asti",
#  'Pater Lieven Kerst Pater Special Christmas',
#  'Wageck Kalkstein Riesling Trocken']

# %%
# Test search names on Vivino
